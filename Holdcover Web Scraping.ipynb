# %%
from selenium import webdriver
import time
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support.ui import Select 
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

# %%
chrome_options = webdriver.ChromeOptions()
# set a headless driver
chrome_options.add_argument('--headless') 
# set the user-agent back to chrome.
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(options=chrome_options)
website = 'https://www.holdcover.com/en/insurance/private-car-quick-quote'
driver.get(website)
driver.maximize_window()
#ignored_exceptions=(NoSuchElementException,StaleElementReferenceException)
#wait = WebDriverWait(driver, 100, ignored_exceptions=ignored_exceptions)
wait = WebDriverWait(driver, 100)
actions = ActionChains(driver)

driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
time.sleep(3)
car_make = wait.until(EC.presence_of_all_elements_located(("xpath","//div[@class='search_scroll']/ul/li")))

all_dict = []

# First loop
for t, car in enumerate(car_make):
    #click the model dropdown button
    car_make_dict = {}
    time.sleep(3)
    if t>0:
    #time.sleep(5)
        #driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
#     print(car.text)
        #wait.until(EC.presence_of_all_elements_located('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span'))
        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
    print("Trial",t)
    #wait.until(EC.presence_of_all_elements_located('xpath', '//div[@class="search_scroll"]/ul/li'))
#     actions.move_to_element(car).perform()
    driver.find_element('xpath',f"//div[@class='search_scroll']/ul/li[{t+1}]").click()
    first_iteration = True
    # Second loop
    while True:
        time.sleep(5)
        dropdown_model_list = wait.until(EC.presence_of_all_elements_located(("xpath",'//*[@name="model_id"]'))) 
        model_dict = {}
        for model in dropdown_model_list:
            v1=model.text.split("\n")
            print(v1)
            break
        for i, model in enumerate(v1):
            driver.refresh()
            time.sleep(5)
            dropdown = Select(driver.find_element("xpath", '//*[@name="model_id"]'))
            dropdown.select_by_visible_text(model)
            print(model)
            #dropdown.select_by_index(i+1)
            #cylinder = driver.find_element('name', 'engn_cpcty')
            try:
                cylinder = driver.find_element('name', 'engn_cpcty')
                cylinder.send_keys('1300')
                year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
                market_value = driver.find_element('name', 'isrd_vl')
                ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
                next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
                year_dropdown.select_by_value('2018')
                market_value.clear()
                time.sleep(2)
                market_value.send_keys('50000')
                ncd.select_by_value('60')
                next_button.click()
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
                Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
                try:
                    #wait.until(EC.element_to_be_clickable('xpath', '//span[@class="amount"]'))
                    #time.sleep(13)
                    wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                        #button_expansion = wait.until(EC.element_to_be_clickable('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]'))
                        #actions.move_to_element(button_expansion).perform()
                    try:
                        button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                    except: pass
                    finally:
                        prices = driver.find_elements('xpath', '//span[@class="amount"]')
                        insurances = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                        for pri in prices:
                            print(pri.text)
                        for ins in insurances:
                            print(ins.text)
                        insurance_dict={ins.text:price.text for price in prices for ins in insurances}
                        model_dict[model]=insurance_dict
                        print(insurance_dict)
                        print(model_dict)
                        time.sleep(3)
                        driver.get(website)
                        time.sleep(3)
                        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click()
                except:
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click()
            except:
                year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
                market_value = driver.find_element('name', 'isrd_vl')
                ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
                next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
                year_dropdown.select_by_value('2018')
                market_value.clear()
                time.sleep(2)
                market_value.send_keys('50000')
                ncd.select_by_value('60')
                next_button.click()
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
                Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
                try:
                    #wait.until(EC.element_to_be_clickable('xpath', '//span[@class="amount"]'))
                    #time.sleep(13)
                    wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                    try:
                        #button_expansion = wait.until(EC.element_to_be_clickable('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]'))
                        #actions.move_to_element(button_expansion).perform()
                        button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                    except: pass
                    finally:
                        prices = driver.find_elements('xpath', '//span[@class="amount"]')
                        insurance = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                        for pri in prices:
                            print(pri.text)
                        for ins in insurances:
                            print(ins.text)
                        insurance_dict={ins:price for price in prices for ins in insurances}
                        model_dict[model]=insurance_dict
                        time.sleep(3)
                        driver.get(website)
                        time.sleep(3)
                        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click()
                except:
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click()
        # Break out of the second loop after the first iteration of the first loop
        #car_make_dict[driver.find_element('xpath',f"//div[@class='search_scroll']/ul/li[{i+1}]").text] = model_dict
        
        if first_iteration:
            break

        # Set the flag to False after the first iteration
        first_iteration = False
    
    car_make_dict[t] = model_dict
    print(car_make_dict)
                
    all_dict.append(car_make_dict)
    print(all_dict)
# Out:
# Trial 0
# ['500', '500C', '595', '595C', 'PUNTO']
# 500
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}}
# 500C
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}}
# 595
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}}
# 595C
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}}
# PUNTO
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}, 'PUNTO': {'AIG': '1,555.92'}}
# {0: {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}, 'PUNTO': {'AIG': '1,555.92'}}}
# ...

# %%
chrome_options = webdriver.ChromeOptions()
# set a headless driver
chrome_options.add_argument('--headless') 
# set the user-agent back to chrome.
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.50 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(options=chrome_options)
website = 'https://www.holdcover.com/en/insurance/private-car-quick-quote'
driver.get(website)
driver.maximize_window()
#ignored_exceptions=(NoSuchElementException,StaleElementReferenceException)
#wait = WebDriverWait(driver, 100, ignored_exceptions=ignored_exceptions)
wait = WebDriverWait(driver, 100)
actions = ActionChains(driver)

driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
time.sleep(3)
car_make = wait.until(EC.presence_of_all_elements_located(("xpath","//div[@class='search_scroll']/ul/li")))

all_dict = []

# First loop
for t, car in enumerate(car_make):
    #click the model dropdown button
    car_make_dict = {}
    time.sleep(3)
    if t>0: #click the button again in later loop
        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
    print("Trial",t)
    driver.find_element('xpath',f"//div[@class='search_scroll']/ul/li[{t+1}]").click() #click the car make
    first_iteration = True
    # Second loop
    while True:
        time.sleep(5)
        dropdown_model_list = wait.until(EC.presence_of_all_elements_located(("xpath",'//*[@name="model_id"]')))
        model_dict = {}
        if first_iteration:
            models= [model.text.split("\n") for model in dropdown_model_list] #getting the static model list
            print (models)
            first_iteration=False 
        for i, model in enumerate(models[0]): #build something in model
            driver.refresh()
            time.sleep(5)
            dropdown = Select(driver.find_element("xpath", '//*[@name="model_id"]'))
            dropdown.select_by_visible_text(model)
            print(model)
            #dropdown.select_by_index(i+1)
            #cylinder = driver.find_element('name', 'engn_cpcty')
            try:
                cylinder = driver.find_element('name', 'engn_cpcty')
                cylinder.send_keys('1300')
                year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
                market_value = driver.find_element('name', 'isrd_vl')
                ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
                next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
                year_dropdown.select_by_value('2018')
                market_value.clear()
                time.sleep(2)
                market_value.send_keys('50000')
                ncd.select_by_value('60')
                next_button.click()
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
                Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
                try:
                    #wait.until(EC.element_to_be_clickable('xpath', '//span[@class="amount"]'))
                    #time.sleep(13)
                    wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                        #button_expansion = wait.until(EC.element_to_be_clickable('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]'))
                        #actions.move_to_element(button_expansion).perform()
                    try:
                        button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                    except: pass
                    finally:
                        prices = driver.find_elements('xpath', '//span[@class="amount"]')
                        insurances = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                        for pri in prices:
                            print(pri.text)
                        for ins in insurances:
                            print(ins.text)
                        insurance_dict={ins.text:price.text for price in prices for ins in insurances}
                        model_dict[model]=insurance_dict
                        print(insurance_dict)
                        print(model_dict)
                        time.sleep(3)
                        driver.get(website)
                        time.sleep(3)
                        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
                except:
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
            except:
                year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
                market_value = driver.find_element('name', 'isrd_vl')
                ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
                next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
                year_dropdown.select_by_value('2018')
                market_value.clear()
                time.sleep(2)
                market_value.send_keys('50000')
                ncd.select_by_value('60')
                next_button.click()
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
                Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
                try:
                    #wait.until(EC.element_to_be_clickable('xpath', '//span[@class="amount"]'))
                    #time.sleep(13)
                    wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                    try:
                        #button_expansion = wait.until(EC.element_to_be_clickable('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]'))
                        #actions.move_to_element(button_expansion).perform()
                        button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                    except: pass
                    finally:
                        prices = driver.find_elements('xpath', '//span[@class="amount"]')
                        insurance = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                        for pri in prices:
                            print(pri.text)
                        for ins in insurances:
                            print(ins.text)
                        insurance_dict={ins:price for price in prices for ins in insurances}
                        model_dict[model]=insurance_dict
                        time.sleep(3)
                        driver.get(website)
                        time.sleep(3)
                        driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
                except:
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
        
        #car_make_dict[driver.find_element('xpath',f"//div[@class='search_scroll']/ul/li[{i+1}]").text] = model_dict
        # Break out of the first loop after the first iteration of the first loop
        if i>len(models)-1:
            break
    
    car_make_dict[t] = model_dict
    print(car_make_dict)
                
    all_dict.append(car_make_dict)
    print(all_dict)
# Out:
# Trial 0
# [['500', '500C', '595', '595C', 'PUNTO']]
# 500
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}}
# 500C
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}}
# 595
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}}
# 595C
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}}
# PUNTO
# 1,555.92
# AIG
# {'AIG': '1,555.92'}
# {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}, 'PUNTO': {'AIG': '1,555.92'}}
# {0: {'500': {'AIG': '1,555.92'}, '500C': {'AIG': '1,555.92'}, '595': {'AIG': '1,555.92'}, '595C': {'AIG': '1,555.92'}, 'PUNTO': {'AIG': '1,555.92'}}}
# ...

# %%
all_dict
# Out:
# [{0: {'500': {'AIG': '1,555.92'},
#    '500C': {'AIG': '1,555.92'},
#    '595': {'AIG': '1,555.92'},
#    '595C': {'AIG': '1,555.92'},
#    'PUNTO': {'AIG': '1,555.92'}}},
#  {1: {'146': {'Dah Sing Insurance': '1,360.92',
#     'AXA': '1,360.92',
#     'BOC Group': '1,360.92'},
#    '147': {'Dah Sing Insurance': '2,014.16',
#     'AXA': '2,014.16',
#     'AIG': '2,014.16',
#     'China PingAn': '2,014.16',
#     'BOC Group': '2,014.16'},
#    '155': {'Dah Sing Insurance': '1,360.92',
#     'AXA': '1,360.92',
#     'BOC Group': '1,360.92'},
#    '156': {'Dah Sing Insurance': '2,014.16',
#     'AXA': '2,014.16',
#     'Allianz': '2,014.16',
#     'AIG': '2,014.16',
#     'China PingAn': '2,014.16',
#     'BOC Group': '2,014.16'},
#    '159': {'Dah Sing Insurance': '2,014.16',
#     'AXA': '2,014.16',
#     'Allianz': '2,014.16',
#     'AIG': '2,014.16',
#     'China PingAn': '2,014.16',
#     'BOC Group': '2,014.16'},
#    '164': {'Dah Sing Insurance': '1,555.92',
# ...

# %%
def select_car_make(x):
    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/section/div/div[2]/div/div/div/div/div/div/span').click()
    time.sleep(3)
    driver.find_element('xpath',f"//div[@class='search_scroll']/ul/li[{x}]").click()
    
def select_car_model():
    dropdown_model_list = wait.until(EC.presence_of_all_elements_located(("xpath",'//*[@name="model_id"]')))
    models= [model.text.split("\n") for model in dropdown_model_list] #getting the static model list
    print (models)
    for i, model in enumerate(models[0]): #build something in model
        driver.refresh()
        time.sleep(5)
        dropdown = Select(driver.find_element("xpath", '//*[@name="model_id"]'))
        dropdown.select_by_visible_text(model)
        print(model)
        try:
            cylinder = driver.find_element('name', 'engn_cpcty')
            cylinder.send_keys('1300')
            year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
            market_value = driver.find_element('name', 'isrd_vl')
            ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
            next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
            year_dropdown.select_by_value('2018')
            market_value.clear()
            time.sleep(2)
            market_value.send_keys('50000')
            ncd.select_by_value('60')
            next_button.click()
            time.sleep(3)
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
            Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
            try:
                wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                try:
                    button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                except: pass
                finally:
                    prices = driver.find_elements('xpath', '//span[@class="amount"]')
                    insurances = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                    for pri in prices:
                        print(pri.text)
                    for ins in insurances:
                          print(ins.text)
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
            except:
                time.sleep(3)
                driver.get(website)
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
        except:
            year_dropdown = Select(driver.find_element('xpath', '//*[@name="rgtn_yr"]'))
            market_value = driver.find_element('name', 'isrd_vl')
            ncd = Select(driver.find_element('xpath', '//*[@name="ncd_pct"]'))
            next_button = driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button')
            year_dropdown.select_by_value('2018')
            market_value.clear()
            time.sleep(2)
            market_value.send_keys('50000')
            ncd.select_by_value('60')
            next_button.click()
            time.sleep(3)
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[1]/div/div/div/div/div/div[2]/div[1]/span').click()
            Select(driver.find_element('xpath', '//*[@name="nm_drvr_age_id"]')).select_by_value('26')
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[2]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[3]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[2]/form/div/div[4]/div/div/div/div/div/div[2]/div[1]/span').click()
            driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[3]/button').click()
            try:
                wait.until(EC.text_to_be_present_in_element(('xpath', '//p[@class="filter-results"]'), 'results'))
                try:
                    button_expansion = driver.find_element('xpath', '//button[@class="v-button flex-center button--cobalt button--pd--default is-round is-transition w-fill"]').click()
                except: pass
                finally:
                    prices = driver.find_elements('xpath', '//span[@class="amount"]')
                    insurance = driver.find_elements('xpath', '//span[@class="block font-regular-4 fw-500-in"]')
                    for pri in prices:
                        print(pri.text)
                    for ins in insurances:
                        print(ins.text)
                    time.sleep(3)
                    driver.get(website)
                    time.sleep(3)
                    driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button
            except:
                time.sleep(3)
                driver.get(website)
                time.sleep(3)
                driver.find_element('xpath', '//*[@id="__layout"]/div/div[1]/section[2]/div/div/div[3]/div/div/div[2]/div/div/div/div[2]/div[1]/button').click() #click the model button

def retrieve_prices(x):
    select_car_make(x)
    time.sleep(3)
    select_car_model()
    
retrieve_prices(2)
# Out:
# [['146', '147', '155', '156', '159', '164', '166', '168', '2.0I', '4C', 'BRERA', 'GIULIA', 'GIULIETTA', 'GT', 'GTV', 'MAQUILLAGE', 'MITO', 'SPIDER', 'STELVIO']]
# 146
# 1,546.50
# 2,462.14
# 1,360.92
# Dah Sing Insurance
# AXA
# BOC Group
# 147
# 1,546.50
# 2,462.14
# 1,555.92
# 1,757.64
# 2,014.16
# Dah Sing Insurance
# AXA
# AIG
# China PingAn
# BOC Group
# 155
# 1,546.50
# 2,462.14
# 1,360.92
# Dah Sing Insurance
# AXA
# BOC Group
# 156
# 1,546.50
# 2,372.36
# 1,553.62
# 1,555.92
# 1,693.00
# 2,014.16
# Dah Sing Insurance
# AXA
# Allianz
# AIG
# China PingAn
# BOC Group
# 159
# 1,546.50
# 2,372.36
# 1,553.62
# 1,555.92
# 1,628.36
# 2,014.16
# Dah Sing Insurance
# AXA
# Allianz
# AIG
# China PingAn
# BOC Group
# 164
# 1,546.50
# 1,360.92
# 1,555.92
# Dah Sing Insurance
# BOC Group
# AIG
# 166
# 1,546.50
# 2,372.36
# 1,360.92
# Dah Sing Insurance
# AXA
# BOC Group
# 168
# 1,546.50
# 2,372.36
# 2,014.16
# Dah Sing Insurance
# AXA
# BOC Group
# 2.0I
# 1,555.92
# AIG
# 4C
# 4,124.00
# ...
