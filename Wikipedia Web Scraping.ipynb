# %%
from selenium import webdriver
import time
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support.ui import Select 
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from datetime_selenium import send_datetime
from datetime import datetime
import pandas as pd

# %%
driver = webdriver.Chrome()
base_url = 'https://zh.wikipedia.org/zh-tw/%E9%A6%99%E6%B8%AF%E7%A7%81%E4%BA%BA%E5%B1%8B%E8%8B%91%E5%88%97%E8%A1%A8'
driver.maximize_window()
wait = WebDriverWait(driver, 10)

# %%
building_total = []

# %%
driver = webdriver.Chrome()
base_url = 'https://zh.wikipedia.org/zh-tw/%E9%A6%99%E6%B8%AF%E7%A7%81%E4%BA%BA%E5%B1%8B%E8%8B%91%E5%88%97%E8%A1%A8'
driver.maximize_window()
wait = WebDriverWait(driver, 10)
driver.get(base_url)

first_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[1]/tbody/tr/td[1]/a')
two_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[1]')
three_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[1]')
four_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[4]/tbody/tr/td[1]')
five_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[5]/tbody/tr/td[1]')
six_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[6]/tbody/tr/td[1]')
seven_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[7]/tbody/tr/td[1]')
eight_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[8]/tbody/tr/td[1]')
nine_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[9]/tbody/tr/td[1]')
ten_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[10]/tbody/tr/td[1]')
elevel_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[11]/tbody/tr/td[1]')
twelve_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[12]/tbody/tr/td[1]')
thirteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[13]/tbody/tr/td[1]')
fourteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[14]/tbody/tr/td[1]')
fifteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[15]/tbody/tr/td[1]')
sixteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[16]/tbody/tr/td[1]')
seventeen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[17]/tbody/tr/td[1]')
eightteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[18]/tbody/tr/td[1]')
nineteen_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[19]/tbody/tr/td[1]')
twenty_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[20]/tbody/tr/td[1]')
twenty1_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[21]/tbody/tr/td[1]')
twenty2_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[22]/tbody/tr/td[1]')
twenty3_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[23]/tbody/tr/td[1]')
twenty4_tb = driver.find_elements('xpath', '//*[@id="mw-content-text"]/div[1]/table[24]/tbody/tr/td[1]')

time.sleep(3)

for i in range(len(twenty4_tb)):
    print('Trial', i, '\n')
    name = driver.find_element('xpath', f'//*[@id="mw-content-text"]/div[1]/table[24]/tbody/tr[{i+1}]/td[1]').text
    print(name)
    building_total.append([name])
# Out:
# Trial 0
#
# 澄碧邨

# %%
building_total
# Out:
# [['賽西湖大廈'],
#  ['寶馬山花園'],
#  ['海天峰'],
#  ['海景台'],
#  ['雲景台'],
#  ['尚譽'],
#  ['海璇'],
#  ['明園'],
#  ['君譽峰'],
#  ['維港頌'],
#  ['港濤軒'],
#  ['港運城'],
#  ['康福園'],
#  ['海峰園'],
#  ['豪廷峰'],
#  ['莊士維港軒'],
#  ['柏蔚山'],
#  ['港逸軒'],
#  ['健威花園'],
#  ['丹拿花園'],
#  ['康澤花園'],
#  ['富澤花園'],
#  ['和富中心'],
#  ['城市花園'],
#  ['百福大廈'],
#  ['僑冠大廈'],
#  ['君豪峰'],
#  ['御皇臺'],
#  ['惠安苑'],
#  ['Mount Parker Residence'],
#  ['太古城'],
#  ['新威園'],
#  ['栢蕙苑'],
#  ['逸樺園'],
#  ['逸意居'],
#  ['南豐新邨'],
#  ['康怡花園'],
#  ['康景花園'],
#  ['康蕙花園'],
#  ['CASA 880'],
#  ['嘉亨灣'],
#  ['逸濤灣'],
#  ['鯉景灣'],
#  ['THE HOLBORN'],
#  ['君悅軒'],
#  ['御景軒'],
#  ['逸瑆'],
#  ['新成中心'],
#  ['欣景花園'],
#  ['譽·東'],
#  ['Island Residence'],
#  ['柏匯'],
#  ['太安樓'],
#  ['形薈'],
#  ['香島'],
#  ['遠晴'],
#  ['莊士軒'],
#  ['樂融軒'],
#  ['峻峰花園'],
#  ['東威大廈'],
#  ['康華大廈'],
#  ['銀河廣場'],
#  ['筲箕灣中心'],
#  ['譽都'],
#  ['麗東海景豪苑'],
#  ['筲箕灣廣場'],
#  ['杏花邨'],
#  ['杏花園'],
#  ['新翠花園'],
#  ['高威閣'],
#  ['永利中心'],
#  ['灣景園'],
#  ['藍灣半島'],
#  ['金馬倫大廈'],
#  ['山頂道20號'],
#  ['傲璇'],
# ...

# %%
df = pd.DataFrame(building_total)
# Out:
#                  0
# 0            賽西湖大廈
# 1            寶馬山花園
# 2              海天峰
# 3              海景台
# 4              雲景台
# ...            ...
# 1072          海堤灣畔
# 1073          藍天海岸
# 1074  Botanica Bay
# 1075    Whitesands
# 1076           澄碧邨
#
# [1077 rows x 1 columns]

# %%
df.rename(columns = {0:'name'}, inplace = True)

# %%
df
# Out:
#               name
# 0            賽西湖大廈
# 1            寶馬山花園
# 2              海天峰
# 3              海景台
# 4              雲景台
# ...            ...
# 1072          海堤灣畔
# 1073          藍天海岸
# 1074  Botanica Bay
# 1075    Whitesands
# 1076           澄碧邨
#
# [1077 rows x 1 columns]

# %%
df.to_csv('building_list_2.csv',index = False)
